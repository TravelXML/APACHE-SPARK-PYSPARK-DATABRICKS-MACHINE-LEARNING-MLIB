# %% [markdown]
# #### Pyspark Basic Introduction

# %%
# !pip install pyspark
# Out:
# ...
#      |▍
#
# *** WARNING: max output size exceeded, skipping output. ***
#
#      |████████████████████████████████| 317.0 MB 12 kB/s
# ...
#      |████████████████████████████████| 200 kB 50.0 MB/s
# ...
# done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488511 sha256=f2cff3946fe2d0e82663304ea7be6c68b7e1b3045ace34cfb2b306c63935d77e
#   Stored in directory: /root/.cache/pip/wheels/92/09/11/aa01d01a7f005fda8a66ad71d2be7f8aa341bddafb27eee3c7
# Successfully built pyspark
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-20c53852-c3b7-4a5c-ad03-d1d4d043c113/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# Create A Session

# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('Practise').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=2232930185716277#setting/sparkui/0807-050652-9cdwsuhg/driver-3268145547853644604">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
#df_pyspark=spark.read.csv('test1.csv')
df_pyspark=spark.read.csv('/FileStore/shared_uploads/astartupcto@gmail.com/test1.csv')

# %%
df_pyspark=spark.read.option('header','true').csv('/FileStore/shared_uploads/astartupcto@gmail.com/test1.csv')

# %%
type(df_pyspark)
# Out:
# Out[4]: pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: string (nullable = true)
#  |-- Experience: string (nullable = true)
#  |-- Salary: string (nullable = true)
